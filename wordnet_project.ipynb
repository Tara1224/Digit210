# %%
import nltk

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Tara\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Tara\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Tara\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Tara\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
import os
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.corpus import wordnet as wn

# %%
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Tara\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Tara\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Tara\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
folder = "texts"
files = os.listdir(folder)

print(files)
# Out:
# ['ATE1.txt', 'ATE2.txt', 'ATE3.txt']

# %%
def read_file(path):
    with open(path, 'r', encoding='utf-8') as f:
        return f.read()

all_tokens = []

for file in files:
    path = os.path.join(folder, file)
    text = read_file(path)
    
    tokens = word_tokenize(text)
    tokens = [t.lower() for t in tokens]
    
    all_tokens.extend(tokens)

print(len(all_tokens))
# Out:
# 9759

# %%
unique_tokens = set(all_tokens)
print(len(unique_tokens))
# Out:
# 1405

# %%
tagged = pos_tag(unique_tokens)
print(tagged[:20])
# Out:
# [('waking', 'VBG'), ('cracks', 'NNS'), ('w-what', 'WP'), ('her', 'PRP$'), ('at', 'IN'), ('sucking', 'VBG'), ('playfully', 'RB'), ('different', 'JJ'), ('start', 'NN'), ('both', 'DT'), ('times', 'NNS'), ('awake', 'VBP'), ('breathes', 'NNS'), ('ca', 'MD'), ('consciousness', 'VB'), ('sound', 'NN'), ('distracted', 'VBD'), ('bottle', 'JJ'), ('cool', 'JJ'), ('mom', 'NN')]

# %%
verbs = [word for word, tag in tagged if tag.startswith('VB')]
verb_set = set(verbs)

print(len(verb_set))
# Out:
# 353

# %% [markdown]
# from nltk.corpus import wordnet as wn
#
# results = []
#
# for word in sorted(selected_set):
#     lemma = wn.morphy(word)
#     lemma = lemma if lemma else word
#
#     synsets = wn.synsets(lemma)
#
#     if synsets:
#         results.append((word, lemma, len(synsets)))
#         print(f"{word} → {len(synsets)} meanings")

# %%
results = []

for word in sorted(verb_set):
    lemma = wn.morphy(word)
    lemma = lemma if lemma else word
    
    synsets = wn.synsets(lemma)
    
    if synsets:
        results.append((word, lemma, len(synsets)))
        print(f"{word} → {len(synsets)} meanings")
# Out:
# accelerating → 2 meanings
# accounted → 14 meanings
# add → 7 meanings
# adds → 7 meanings
# alright → 4 meanings
# am → 16 meanings
# answering → 15 meanings
# appearance → 6 meanings
# appears → 7 meanings
# approaches → 14 meanings
# are → 14 meanings
# arise → 7 meanings
# arm → 8 meanings
# ask → 7 meanings
# asking → 8 meanings
# assembled → 3 meanings
# attracted → 3 meanings
# awake → 3 meanings
# backpack → 2 meanings
# bandaged → 3 meanings
# banging → 9 meanings
# banned → 9 meanings
# be → 14 meanings
# beat → 34 meanings
# become → 4 meanings
# becomes → 4 meanings
# been → 14 meanings
# begin → 11 meanings
# being → 15 meanings
# biting → 13 meanings
# blew → 29 meanings
# blindfolded → 3 meanings
# blockading → 6 meanings
# blowing → 23 meanings
# bored → 19 meanings
# bouncing → 10 meanings
# brad → 2 meanings
# break → 75 meanings
# breaking → 60 meanings
# broke → 75 meanings
# brought → 11 meanings
# bulges → 5 meanings
# buns → 2 meanings
# bury → 6 meanings
# butler → 3 meanings
# butt → 12 meanings
# buying → 6 meanings
# carries → 41 meanings
# carrying → 41 meanings
# cat → 10 meanings
# causing → 3 meanings
# cell → 7 meanings
# changed → 20 meanings
# changing → 20 meanings
# chasing → 7 meanings
# cheering → 7 meanings
# chew → 3 meanings
# chili → 2 meanings
# choosing → 3 meanings
# collecting → 6 meanings
# comes → 22 meanings
# coming → 26 meanings
# complicated → 2 meanings
# plan → 7 meanings
# play → 52 meanings
# playing → 38 meanings
# prefer → 4 meanings
# princess → 1 meanings
# princesses → 1 meanings
# promised → 6 meanings
# promises → 6 meanings
# prove → 9 meanings
# pushes → 15 meanings
# pushing → 11 meanings
# put → 10 meanings
# putting → 10 meanings
# questioning → 9 meanings
# raised → 31 meanings
# raising → 31 meanings
# read → 12 meanings
# realizes → 6 meanings
# remember → 8 meanings
# replaces → 4 meanings
# resetting → 4 meanings
# retrieve → 4 meanings
# returning → 29 meanings
# revealing → 6 meanings
# revived → 5 meanings
# ringing → 9 meanings
# roundhouse → 2 meanings
# rude → 5 meanings
# ruined → 12 meanings
# running → 52 meanings
# runs → 57 meanings
# said → 12 meanings
# sandwich → 3 meanings
# save → 12 meanings
# say → 12 meanings
# saying → 12 meanings
# says → 12 meanings
# seen → 25 meanings
# serving → 17 meanings
# set → 45 meanings
# shake → 15 meanings
# shaking → 11 meanings
# shaped → 11 meanings
# shed → 6 meanings
# shouting → 6 meanings
# shoveling → 5 meanings
# show → 16 meanings
# showed → 16 meanings
# skull → 1 meanings
# sled → 2 meanings
# sledding → 3 meanings
# sleeping → 6 meanings
# slides → 10 meanings
# slime → 2 meanings
# smash → 16 meanings
# smashed → 16 meanings
# smooth → 12 meanings
# sniffs → 3 meanings
# soars → 6 meanings
# sock → 3 meanings
# socks → 3 meanings
# sorry → 4 meanings
# sort → 6 meanings
# sounds → 24 meanings
# spear → 4 meanings
# squeezes → 17 meanings
# stand → 24 meanings
# starting → 17 meanings
# stop → 22 meanings
# stopping → 13 meanings
# sucking → 8 meanings
# super → 5 meanings
# supposed → 5 meanings
# swinging → 16 meanings
# take → 44 meanings
# takes → 44 meanings
# taking → 44 meanings
# talking → 7 meanings
# tap → 20 meanings
# tearing → 7 meanings
# tell → 9 meanings
# telling → 14 meanings
# tend → 3 meanings
# thinking → 15 meanings
# thought → 17 meanings
# throws → 20 meanings
# tickled → 5 meanings
# tonight → 2 meanings
# transporting → 11 meanings
# trespassing → 7 meanings
# tried → 10 meanings
# tries → 10 meanings
# truth → 5 meanings
# trying → 10 meanings
# tuck → 7 meanings
# turned → 38 meanings
# turning → 32 meanings
# turns → 38 meanings
# used → 13 meanings
# using → 7 meanings
# violating → 6 meanings
# visualizes → 4 meanings
# vowed → 3 meanings
# wait → 6 meanings
# waking → 7 meanings
# wannabe → 1 meanings
# wanted → 9 meanings
# wants → 9 meanings
# warming → 6 meanings
# was → 1 meanings
# were → 14 meanings
# whispering → 4 meanings
# whole → 8 meanings
# win → 6 meanings
# windows → 9 meanings
# worked → 34 meanings
# working → 33 meanings
# works → 38 meanings
# worms → 5 meanings
# worsening → 5 meanings
# yeah → 1 meanings

# %% [markdown]
# The results show that many verbs in the Adventure Time scripts are highly ambiguous according to WordNet. Works has the most meanings of 38. WordNet shows how many interpreations a word can have.

# %%
def save_results(filename, data):
    with open(filename, 'w', encoding='utf-8') as f:
        for word, lemma, count in data:
            f.write(f"{word}\t{lemma}\t{count}\n")

save_results("adventure_time_verbs.txt", results)

# %% [markdown]
# I chose to analyze verbs because they represent action within the text. This is important in a cartoon based show like AdventureTime.

# %% [markdown]
# I struggled with writing loops that went through multiple files and processed all the tokens.
